# %% [markdown]
# ## 7. Βιβλιοθήκες οπτικοποίησης στην Python

# %% [markdown]
# <!-- book-intro-cell -->
# ### Εισαγωγή από το βιβλίο
#
# Η Python διαθέτει ένα πλούσιο οικοσύστημα βιβλιοθηκών για την οπτικοποίηση δεδομένων. Οι βιβλιοθήκες αυτές διαφέρουν ως προς τον βαθμό ελέγχου που παρέχουν, το είδος των γραφημάτων που υποστηρίζουν και το επίπεδο διαδραστικότητας που προσφέρουν. Ορισμένες είναι κατάλληλες για επιστημονικές δημοσιεύσεις και στατικές απεικονίσεις υψηλής ακρίβειας, ενώ άλλες έχουν σχεδιαστεί για διαδραστικές εφαρμογές ή για ειδικούς τύπους δεδομένων, όπως τα γεωχωρικά δεδομένα.
#
# Στο κεφάλαιο αυτό παρουσιάζονται τέσσερις βιβλιοθήκες που χρησιμοποιούνται συχνά στην επιστήμη δεδομένων: Matplotlib, Seaborn, Folium και Plotly. Κάθε μία καλύπτει διαφορετικές ανάγκες οπτικοποίησης και συχνά χρησιμοποιούνται συμπληρωματικά.

# %% [markdown]
# ### Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.title("Παράδειγμα γραφήματος με Matplotlib")
plt.show()

# %%
fig, ax = plt.subplots()

# %%
ax.set_xticks([0, 5, 10])

# %%
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

# %%
ax.set_title("Παράδειγμα γραφήματος")
# Out:
# Text(0.5, 1.0, 'Παράδειγμα γραφήματος')

# %%
ax.legend()
# Out:
# /tmp/ipykernel_628/1491706200.py:1: UserWarning:
#
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
ax.grid(True)

# %%
fig, ax = plt.subplots()
ax.grid(True)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.set_xticks([0, 5, 10])
ax.annotate("σημαντικό σημείο!!", xy=(0,0), xytext=(1, 0.5))
plt.show()

# %% [markdown]
# #### OOP

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)

fig, ax = plt.subplots()

ax.plot(x, np.sin(x), label="sin(x)")
ax.plot(x, np.cos(x), label="cos(x)")

ax.set_xlabel("x")
ax.set_ylabel("τιμή")
ax.set_title("Σύγκριση συναρτήσεων (ο αντικειμενοστραφής δρόμος)")
ax.legend()

plt.show()

# %%
x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x), label="sin(x)")
plt.plot(x, np.cos(x), label="cos(x)")
plt.title("Σύγκριση συναρτήσεων (ο δρόμος μέσω pyplot)")
plt.xlabel("x")
plt.ylabel("Τιμή")
plt.legend()
plt.show()

# %%
x = np.linspace(0, 10, 100)

fig, axes = plt.subplots(1, 2, figsize=(10,4))

axes[0].plot(x, np.sin(x))
axes[0].set_title("sin(x)")

axes[1].plot(x, np.cos(x))
axes[1].set_title("cos(x)")

plt.show()

# %%
x = np.linspace(0, 10, 100)
fig, axes = plt.subplots(1, 2, figsize=(10,4))
axes[0].plot(x, np.sin(x))
axes[0].set_title("sin(x)")
axes[1].plot(x, np.cos(x))
axes[1].set_title("cos(x)")
axes[0].grid(True)
axes[0].spines["top"].set_visible(False)
axes[0].spines["right"].set_visible(False)
plt.show()

# %% [markdown]
# #### Subplots

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)

fig, axes = plt.subplots(1, 2, figsize=(10,4))

axes[0].plot(x, np.sin(x))
axes[0].set_title("sin(x)")

axes[1].plot(x, np.cos(x))
axes[1].set_title("cos(x)")

plt.show()

# %% [markdown]
# #### Parameterization

# %%
plt.plot(x, y, color="darkblue", linestyle="--", linewidth=2);

# %% [markdown]
# #### Saving

# %%
plt.savefig("figure.png", dpi=600)
plt.savefig("figure.pdf", dpi=400)
plt.savefig("figure.svg", dpi=300)

# %% [markdown]
# ### Seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")

sns.scatterplot(data=tips, x="total_bill", y="tip", hue="day")
plt.title("Συσχέτιση λογαριασμού και φιλοδωρήματος")
plt.show()

# %% [markdown]
# ### Folium

# %%
import folium

map = folium.Map(location=[37.98, 23.72], zoom_start=12)

folium.Marker(
    location=[37.98, 23.72],
    popup="Κέντρο Αθήνας"
).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# ### Plotly

# %%
import plotly.express as px

df = px.data.iris()

fig = px.scatter(
    df,
    x="sepal_width",
    y="sepal_length",
    color="species",
    title="Διαδραστικό γράφημα Plotly"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
